# %%
import os

print(os.listdir('/kaggle/input/datasets/odins0n'))
# Out:
# ['ucf-crime-dataset']

# %%
print(os.listdir('/kaggle/input/datasets/odins0n/ucf-crime-dataset'))
# Out:
# ['Test', 'Train']

# %%
import os

train_path = "/kaggle/input/datasets/odins0n/ucf-crime-dataset/Train"

print(os.listdir(train_path))
# Out:
# ['RoadAccidents', 'Assault', 'Vandalism', 'Arrest', 'Shooting', 'NormalVideos', 'Arson', 'Explosion', 'Shoplifting', 'Robbery', 'Stealing', 'Burglary', 'Abuse', 'Fighting']

# %%
print(os.listdir(train_path + "/Robbery")[:5])
# Out:
# ['Robbery026_x264_10910.png', 'Robbery034_x264_1210.png', 'Robbery027_x264_4840.png', 'Robbery021_x264_210.png', 'Robbery129_x264_240.png']

# %%
import os
import cv2
import numpy as np

train_path = "/kaggle/input/datasets/odins0n/ucf-crime-dataset/Train"

frames = []
labels = []

classes = os.listdir(train_path)

for class_name in classes:

    class_path = os.path.join(train_path, class_name)

    images = os.listdir(class_path)[:50]   # limit to 50 images

    for img in images:

        img_path = os.path.join(class_path, img)

        image = cv2.imread(img_path)

        if image is None:
            continue

        image = cv2.resize(image,(64,64))

        frames.append(image)

        if class_name == "NormalVideos":
            labels.append(0)
        else:
            labels.append(1)

print("Images loaded:", len(frames))
# Out:
# Images loaded: 700

# %%
import os
import cv2
import numpy as np

train_path = "/kaggle/input/datasets/odins0n/ucf-crime-dataset/Train"

frames = []
labels = []

classes = os.listdir(train_path)

for class_name in classes:

    print("Processing class:", class_name)

    class_path = os.path.join(train_path, class_name)

    images = os.listdir(class_path)[:50]   # smaller limit

    for img in images:

        img_path = os.path.join(class_path, img)

        image = cv2.imread(img_path)

        if image is None:
            continue

        image = cv2.resize(image,(64,64))

        frames.append(image)

        if class_name == "NormalVideos":
            labels.append(0)
        else:
            labels.append(1)

print("Images loaded:", len(frames))
# Out:
# Processing class: RoadAccidents
# Processing class: Assault
# Processing class: Vandalism
# Processing class: Arrest
# Processing class: Shooting
# Processing class: NormalVideos
# Processing class: Arson
# Processing class: Explosion
# Processing class: Shoplifting
# Processing class: Robbery
# Processing class: Stealing
# Processing class: Burglary
# Processing class: Abuse
# Processing class: Fighting
# Images loaded: 700

# %%
X = np.array(frames)
y = np.array(labels)

X = X / 255.0

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(64,64,3)),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])
# Out:
# 2026-03-24 12:48:31.712648: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774356511.947278      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774356512.017403      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774356512.597129      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.9093 - loss: 0.4125
# Epoch 2/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9358 - loss: 0.2505
# Epoch 3/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.9284 - loss: 0.2408
# Epoch 4/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9187 - loss: 0.2241
# Epoch 5/5
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.9365 - loss: 0.1666

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
print(os.listdir("/kaggle/working"))
# Out:
# ['model.h5', '__notebook__.ipynb']

# %%
import keras
import tensorflow as tf

print("Keras version:", keras.__version__)
print("TensorFlow version:", tf.__version__)
# Out:
# Keras version: 3.10.0
# TensorFlow version: 2.19.0

# %% [markdown]
# 🎉
